# %%
import pandas as pd
import numpy as np
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('results_iterations_1000.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  accuracy  n_estimators  max_features  max_depth criterion  \
# 0           0  0.709436           823          0.75       98.0   entropy
# 1           1  0.710931           980          0.55       45.0   entropy
# 2           2  0.704953           543          0.75       96.0   entropy
# 3           3  0.711998           654          0.90       99.0   entropy
# 4           4  0.707728           613          0.60       71.0      gini
#
#    n_jobs
# 0      -1
# 1      -1
# 2      -1
# 3      -1
# 4      -1

# %%
df.sort_values(['accuracy'], ascending=False)[0:50]
# Out:
#      Unnamed: 0  accuracy  n_estimators  max_features  max_depth criterion  \
# 335         335  0.721178           973          0.65       87.0      gini
# 919         919  0.720751           604          0.95       46.0      gini
# 566         566  0.717763           961          0.60       81.0   entropy
# 594         594  0.716909           303          0.90       28.0   entropy
# 635         635  0.716909           670          0.70       52.0   entropy
# 866         866  0.716482           541          0.65       66.0      gini
# 12           12  0.716055           537          0.80       61.0   entropy
# 417         417  0.715841           267          0.85       41.0   entropy
# 670         670  0.715414           861          0.75       81.0      gini
# 29           29  0.714987           699          0.55       14.0   entropy
# 929         929  0.714987           736          0.70       16.0   entropy
# 774         774  0.714560           646          0.90       15.0   entropy
# 648         648  0.714560           863          0.65       33.0      gini
# 164         164  0.714347           957          0.55       99.0      gini
# 175         175  0.713920           837          0.75       47.0      gini
# 784         784  0.713920           216          0.50       88.0      gini
# 661         661  0.713706           390          0.55       47.0      gini
# 54           54  0.713706           972          0.60       25.0   entropy
# 117         117  0.713706           305          0.65       78.0   entropy
# 640         640  0.713493           687          0.75       93.0      gini
# 922         922  0.713493           642          0.50       64.0      gini
# 936         936  0.713493           515          0.60       28.0      gini
# 571         571  0.713279           635          0.55       47.0   entropy
# 536         536  0.713279           629          0.55       79.0   entropy
# 604         604  0.713066           322          0.55       31.0   entropy
# 136         136  0.712852           778          0.75       93.0      gini
# 399         399  0.712639           397          0.75       83.0   entropy
# 645         645  0.712425           244          0.70       97.0   entropy
# 470         470  0.712212           950          0.50       44.0      gini
# 154         154  0.712212           532          0.90       97.0      gini
# 948         948  0.712212           923          0.55       86.0      gini
# 511         511  0.711998           973          0.80       10.0   entropy
# 833         833  0.711998           225          0.50       22.0   entropy
# 429         429  0.711998           702          0.50       88.0   entropy
# 452         452  0.711998           391          0.65       84.0      gini
# 542         542  0.711998           909          0.90       40.0   entropy
# 3             3  0.711998           654          0.90       99.0   entropy
# 22           22  0.711998           539          0.85       91.0      gini
# 45           45  0.711785           831          0.55       89.0      gini
# 313         313  0.711785           619          0.70       77.0      gini
# 315         315  0.711785           757          0.85       42.0   entropy
# 183         183  0.711785           828          0.70       23.0   entropy
# 619         619  0.711571           426          0.80       41.0      gini
# 70           70  0.711571           624          0.75       87.0      gini
# 686         686  0.711571           350          0.75       54.0      gini
# 418         418  0.711571           380          0.55       43.0   entropy
# 395         395  0.711571           590          0.80       89.0   entropy
# 864         864  0.711571           236          0.85       24.0   entropy
# 427         427  0.711358           408          0.65       36.0      gini
# 423         423  0.711358           535          0.60       60.0      gini
#
#      n_jobs
# 335      -1
# 919      -1
# 566      -1
# 594      -1
# 635      -1
# 866      -1
# 12       -1
# 417      -1
# 670      -1
# 29       -1
# 929      -1
# 774      -1
# 648      -1
# 164      -1
# 175      -1
# 784      -1
# 661      -1
# 54       -1
# 117      -1
# 640      -1
# 922      -1
# 936      -1
# 571      -1
# 536      -1
# 604      -1
# 136      -1
# 399      -1
# 645      -1
# 470      -1
# 154      -1
# 948      -1
# 511      -1
# 833      -1
# 429      -1
# 452      -1
# 542      -1
# 3        -1
# 22       -1
# 45       -1
# 313      -1
# 315      -1
# 183      -1
# 619      -1
# 70       -1
# 686      -1
# 418      -1
# 395      -1
# 864      -1
# 427      -1
# 423      -1
